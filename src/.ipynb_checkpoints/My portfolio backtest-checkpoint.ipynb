# %% [markdown]
# # Backtest of my portfolio
#
# Jupyter notebook to test how my current portfolio performs.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# ## Short term backtest

# %% [markdown]
# Leverage 1

# %%
# %run main --shares "TLT,VNQ,IEF,QQQ,SPY,XLU,DBC,GLD" --shareclass "bond_lt,bond_lt,bond_it,equity,equity,commodity,commodity,gold" --strategy uniform,onlystocks,sixtyforty,riskparity_nested --initial_cash 100000 --contribution 0 --create_report --report_name MyPortofolio_Short_lev1 --startdate "2004-06-01" --enddate "2020-11-01" --system windows --leverage 1

# %% [markdown]
# Leverage 2

# %%
# %run main --shares "TLT,VNQ,IEF,QQQ,SPY,XLU,DBC,GLD" --shareclass "bond_lt,bond_lt,bond_it,equity,equity,commodity,commodity,gold" --strategy uniform,onlystocks,sixtyforty,riskparity_nested --initial_cash 100000 --contribution 0 --create_report --report_name MyPortofolio_Short_lev2 --startdate "2004-06-01" --enddate "2020-11-01" --system windows --leverage 2

# %% [markdown]
# Leverage 3

# %%
# %run main --shares "TLT,VNQ,IEF,QQQ,SPY,XLU,DBC,GLD" --shareclass "bond_lt,bond_lt,bond_it,equity,equity,commodity,commodity,gold" --strategy uniform,onlystocks,sixtyforty,riskparity_nested --initial_cash 100000 --contribution 0 --create_report --report_name MyPortofolio_Short_lev3 --startdate "2004-06-01" --enddate "2020-11-01" --system windows --leverage 3
# Out:
# C:\Users\feder\Anaconda3\envs\portfolio-allocation\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\Desktop\portfolio-allocation\src\main.py in <module>
#     219     # Clear the output folder
#     220     outputdir = os.path.join(os.path.abspath(os.path.join(os.getcwd(), os.pardir)), "output")
# --> 221     delete_in_dir(outputdir)
#     222
#     223     print_header(args)
#
# ~\Desktop\portfolio-allocation\src\utils.py in delete_in_dir(mydir, *args, **kwargs)
#      83
#      84     for f in filelist:
# ---> 85         os.remove(os.path.join(mydir, f))
#      86
#      87
#
# ...

# %% [markdown]
# ## Medium term backtest

# %% [markdown]
# Leverage 1

# %%
# %run main --historic "medium" --shares GLD,COM,SP500TR,LTB,ITB --strategy uniform --initial_cash 100000 --contribution 0 --create_report --report_name MyPortofolio_Medium_lev1 --startdate "1980-01-01" --enddate "2020-01-01" --system windows --leverage 1

# %% [markdown]
# Leverage 2

# %%
# %run main --historic "medium" --shares GLD,COM,SP500TR,LTB,ITB --strategy uniform --initial_cash 100000 --contribution 0 --create_report --report_name MyPortofolio_Medium_lev --startdate "1980-01-01" --enddate "2020-01-01" --system windows --leverage 2
# Out:
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic medium
# ###    --shares GLD,COM,SP500TR,LTB,ITB
# ###    --shareclass None
# ###    --weights
# ###    --indicators False
# ###    --initial_cash 100000
# ###    --contribution 0.0
# ###    --create_report True
# ###    --report_name MyPortofolio_Medium_lev
# ###    --strategy uniform
# ###    --startdate 1980-01-01
# ###    --enddate 2020-01-01
# ###    --system windows
# ###    --leverage 2
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: uniform
# ###
# ##############################################################################
# 2020-01-01, Strategy: you are using data with daily frequency
# ...

# %% [markdown]
# Leverage 3

# %%
# %run main --historic "medium" --shares GLD,COM,SP500TR,LTB,ITB --strategy uniform --initial_cash 100000 --contribution 0 --create_report --report_name MyPortofolio_Medium_lev3 --startdate "1980-01-01" --enddate "2020-01-01" --system windows --leverage 3

# %% [markdown]
# ## Long term backtest

# %% [markdown]
# Leverage 1

# %%
# %run main --historic "long" --shares GLD_LNG,OIL_LNG,EQ_LNG,US10YB_LNG,RE_LNG,LTB_LNG --strategy uniform,onlystocks,vanillariskparity,sixtyforty,riskparity --initial_cash 1000000 --contribution 0 --create_report --report_name MyPortofolio_Long_lev1 --startdate "1905-01-01" --enddate "2015-01-01" --system windows --leverage 1

# %% [markdown]
# Leverage 2

# %%
# %run main --historic "long" --shares GLD_LNG,OIL_LNG,EQ_LNG,US10YB_LNG,RE_LNG,LTB_LNG --strategy uniform,onlystocks,vanillariskparity,sixtyforty,riskparity --initial_cash 1000000 --contribution 0 --create_report --report_name MyPortofolio_Long_lev2 --startdate "1905-01-01" --enddate "2015-01-01" --system windows --leverage 2

# %% [markdown]
# Leverage 3

# %%
# %run main --historic "long" --shares GLD_LNG,OIL_LNG,EQ_LNG,US10YB_LNG,RE_LNG,LTB_LNG --strategy uniform,onlystocks,vanillariskparity,sixtyforty,riskparity --initial_cash 1000000 --contribution 0 --create_report --report_name MyPortofolio_Long_lev3 --startdate "1905-01-01" --enddate "2015-01-01" --system windows --leverage 3
