# %% [markdown]
# # Backtest
# Jupyter notebook needed to show pyfolio report

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %run main --shares SPY --shareclass "equity" --strategy onlystocks,uniform --initial_cash 100000 --monthly_cash 0 --create_report --report_name MyCurrentPortfolio --startdate "2018-01-01" --enddate "2020-06-30" --system windows --leverage 3
# Out:
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic False
# ###    --shares SPY
# ###    --shareclass equity
# ###    --weights
# ###    --indicators False
# ###    --initial_cash 100000
# ###    --monthly_cash 0.0
# ###    --create_report True
# ###    --report_name MyCurrentPortfolio
# ###    --strategy onlystocks,uniform
# ###    --startdate 2018-01-01
# ###    --enddate 2020-06-30
# ###    --system windows
# ###    --leverage 3
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: onlystocks
# ###
# ##############################################################################
# 2018-01-22, MONTHLY CASH ADDED: new cash amount is 100000
# ...
