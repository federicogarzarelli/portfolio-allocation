# %% [markdown]
# # My portfolio backtest
#
# Jupyter notebook to test how my current portfolio has performed.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# Leverage 1 different portfolio allocations

# %%
    # %run main --shares "UBT,UST,ROM,MVV,EMQQ,ICLN,DIG,UYM,UPW,UGL" --shareclass "bond_lt,bond_it,equity,equity,equity,commodity,commodity,commodity,commodity,gold" --benchmark "RPAR" --strategy uniform,onlystocks,sixtyforty,riskparity_nested --initial_cash 100000 --contribution 0 --create_report --report_name CurrentPortfolio --startdate "2020-07-01" --enddate "2021-03-14" --system windows --leverage 2
# Out:
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic None
# ###    --shares UBT,UST,ROM,MVV,EMQQ,ICLN,DIG,UYM,UPW,UGL
# ###    --shareclass bond_lt,bond_it,equity,equity,equity,commodity,commodity,commodity,commodity,gold
# ###    --weights
# ###    --indicators False
# ###    --initial_cash 100000
# ###    --contribution 0.0
# ###    --create_report True
# ###    --report_name CurrentPortfolio
# ###    --strategy uniform,onlystocks,sixtyforty,riskparity_nested
# ###    --startdate 2020-07-01
# ###    --enddate 2021-03-14
# ###    --system windows
# ###    --leverage 2.0
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: uniform
# ###
# ...

# %% [markdown]
# Weights

# %%
# %run main --shares "UBT,UST,ROM,MVV,EMQQ,ICLN,DIG,UYM,UPW,UGL" --shareclass "bond_lt,bond_it,equity,equity,equity,commodity,commodity,commodity,commodity,gold" --weights 0.1,0.3,0.07,0.1,0.03,0.05,0.05,0.05,0.05,0.2 --benchmark "SPY" --initial_cash 100000 --contribution 0 --create_report --report_name CurrentPortfolio --startdate "2020-12-01" --enddate "2021-03-14" --system windows --leverage 1
# Out:
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic None
# ###    --shares UBT,UST,ROM,MVV,EMQQ,ICLN,DIG,UYM,UPW,UGL
# ###    --shareclass bond_lt,bond_it,equity,equity,equity,commodity,commodity,commodity,commodity,gold
# ###    --weights 0.1,0.3,0.07,0.1,0.03,0.05,0.05,0.05,0.05,0.2
# ###    --indicators False
# ###    --initial_cash 100000
# ###    --contribution 0.0
# ###    --create_report True
# ###    --report_name CurrentPortfolio
# ###    --strategy None
# ###    --startdate 2020-12-01
# ###    --enddate 2021-03-14
# ###    --system windows
# ###    --leverage 1.0
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: customweights
# ###
# ...

# %% [markdown]
# ### Covid Nov'19 - Mar'21

# %% [markdown]
# Leverage 2 ETFs

# %%
# %run main --shares "MVV,ROM,EMQQ,ICLN,UGL,DIG,UYM,UST,UBT" --shareclass "equity,equity,equity,equity,gold,commodity,commodity,bond_it,bond_lt"  --weights "0.1,0.05,0.025,0.025,0.2, 0.1, 0.1, 0.3,0.1" --benchmark "RPAR" --initial_cash 320000 --contribution 0 --create_report --report_name CovidLev2 --startdate "2019-11-01" --enddate "2021-03-30" --system windows --leverage 1
# Out:
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic None
# ###    --shares MVV,ROM,EMQQ,ICLN,UGL,DIG,UYM,UST,UBT
# ###    --shareclass equity,equity,equity,equity,gold,commodity,commodity,bond_it,bond_lt
# ###    --weights 0.1,0.05,0.025,0.025,0.2, 0.1, 0.1, 0.3,0.1
# ###    --indicators False
# ###    --initial_cash 320000
# ###    --contribution 0.0
# ###    --create_report True
# ###    --report_name CovidLev2
# ###    --strategy None
# ###    --startdate 2019-11-01
# ###    --enddate 2021-03-30
# ###    --system windows
# ###    --leverage 1.0
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: customweights
# ###
# ...

# %% [markdown]
# Leverage 1 ETFs

# %%
# %run main --shares "SPY,QQQ,EMQQ,ICLN,GLD,XLE,IEF,TLT" --shareclass "equity,equity,equity,equity,gold,commodity,bond_it,bond_lt"  --weights "0.1,0.05,0.025,0.025,0.2,0.2,0.3,0.1" --initial_cash 320000 --contribution 0 --create_report --report_name CovidLev1 --startdate "2019-11-01" --enddate "2021-03-30" --system windows --leverage 1
# Out:
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic None
# ###    --shares SPY,QQQ,EMQQ,ICLN,GLD,XLE,IEF,TLT
# ###    --shareclass equity,equity,equity,equity,gold,commodity,bond_it,bond_lt
# ###    --weights 0.1,0.05,0.025,0.025,0.2,0.2,0.3,0.1
# ###    --indicators False
# ###    --initial_cash 320000
# ###    --contribution 0.0
# ###    --create_report True
# ###    --report_name CovidLev1
# ###    --strategy None
# ###    --startdate 2019-11-01
# ###    --enddate 2021-03-30
# ###    --system windows
# ###    --leverage 1.0
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: customweights
# ###
# ##############################################################################
# ...
