# %% [markdown]
# # Backtest
# Jupyter notebook to run the backtesting program (needed to show pyfolio report).
#
# This is a base and general version contaning examples from the Readme file. Please refer to the Readme file for more details on the arguments.
#
# Please save a new copy for specific analysis.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# ### 0. Tests

# %%
# %run main --shares "3GLD,TYD,UTSL,TMF,TQQQ,UPRO" --shareclass "gold,bond_it,commodity,bond_lt,equity,equity" --strategy uniform,riskparity_nested --initial_cash 150000 --create_report --report_name current_portfolio --startdate "2020-01-15" --enddate "2020-10-12" --system windows --leverage 1
# Out:
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic None
# ###    --shares 3GLD,TYD,UTSL,TMF,TQQQ,UPRO
# ###    --shareclass gold,bond_it,commodity,bond_lt,equity,equity
# ###    --weights
# ###    --indicators False
# ###    --initial_cash 150000
# ###    --monthly_cash 10000
# ###    --create_report True
# ###    --report_name current_portfolio
# ###    --strategy uniform,riskparity_nested
# ###    --startdate 2020-01-15
# ###    --enddate 2020-10-12
# ###    --system windows
# ###    --leverage 1
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: uniform
# ###
# ##############################################################################
# ...

# %%
# %run main --shares "GLD,IEF,VPU,TLT,QQQ,SPY" --shareclass "gold,bond_it,commodity,bond_lt,equity,equity" --strategy uniform,riskparity_nested --initial_cash 150000 --monthly_cash 10000 --create_report --report_name current_portfolio --startdate "2020-01-15" --enddate "2020-09-29" --system windows --leverage 3
# Out:
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic None
# ###    --shares GLD,IEF,VPU,TLT,QQQ,SPY
# ###    --shareclass gold,bond_it,commodity,bond_lt,equity,equity
# ###    --weights
# ###    --indicators False
# ###    --initial_cash 150000
# ###    --monthly_cash 10000.0
# ###    --create_report True
# ###    --report_name current_portfolio
# ###    --strategy uniform,riskparity_nested
# ###    --startdate 2020-01-15
# ###    --enddate 2020-09-29
# ###    --system windows
# ###    --leverage 3
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: uniform
# ###
# ##############################################################################
# ...

# %% [markdown]
# ### 1. Historical data, uniform strategy

# %%
# %run main --historic "medium" --shares GLD,COM,SP500,LTB,ITB --strategy uniform --initial_cash 100000 --monthly_cash 10000 --create_report --report_name example --startdate "2015-01-01" --enddate "2020-01-01" --system windows --leverage 3
# Out:
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic medium
# ###    --shares GLD,COM,SP500,LTB,ITB
# ###    --shareclass None
# ###    --weights
# ###    --indicators False
# ###    --initial_cash 100000
# ###    --monthly_cash 10000.0
# ###    --create_report True
# ###    --report_name example
# ###    --strategy uniform
# ###    --startdate 2015-01-01
# ###    --enddate 2020-01-01
# ###    --system windows
# ###    --leverage 3
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: uniform
# ###
# ##############################################################################
# 2020-01-01, Strategy: you are using data with daily frequency
# ...

# %% [markdown]
# ### 2. Historical data, custom weights

# %%
# %run main --historic  "medium" --shares GLD,COM,SP500,LTB,ITB --weights "0.2, 0.3, 0.1, 0.1, 0.3" --initial_cash 100000 --monthly_cash 10000 --create_report --report_name example --startdate "2015-01-01" --enddate "2020-01-01" --system windows --leverage 3

# %% [markdown]
# ### 3. Automatically downloaded data, custom weights

# %%
# %run main --shares "SPY,IWM,TLT,GLD," --shareclass "equity,equity,bond_lt,gold" --weights "0.2, 0.3, 0.1, 0.4" --initial_cash 100000 --monthly_cash 10000 --create_report --report_name example --startdate "2015-01-01" --enddate "2020-01-01" --system windows --leverage 3

# %% [markdown]
# ### 4. Automatically downloaded data, 60-40 strategy

# %%
# %run main --shares "SPY,IWM,TLT,GLD," --shareclass "equity,equity,bond_lt,gold" --strategy sixtyforty --initial_cash 100000 --monthly_cash 10000 --create_report --report_name example --startdate "2015-01-01" --enddate "2020-01-01" --system windows --leverage 3

# %% [markdown]
# ### 5. Multiple strategies backtest

# %%
# %run main --shares "UPRO,TQQQ,UGLD,TYD,TMF,UTSL" --shareclass "equity,equity,gold,bond_it,bond_lt,commodity" --strategy riskparity_nested,riskparity,uniform,sixtyforty,onlystocks --initial_cash 100000 --monthly_cash 10000 --create_report --report_name MyCurrentPortfolio --startdate "2019-06-01" --enddate "2020-09-29" --system windows --leverage 1
# Out:
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic None
# ###    --shares UPRO,TQQQ,UGLD,TYD,TMF,UTSL
# ###    --shareclass equity,equity,gold,bond_it,bond_lt,commodity
# ###    --weights
# ###    --indicators False
# ###    --initial_cash 100000
# ###    --monthly_cash 10000.0
# ###    --create_report True
# ###    --report_name MyCurrentPortfolio
# ###    --strategy riskparity_nested,riskparity,uniform,sixtyforty,onlystocks
# ###    --startdate 2019-06-01
# ###    --enddate 2020-09-29
# ###    --system windows
# ###    --leverage 1
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: riskparity_nested
# ###
# ...
