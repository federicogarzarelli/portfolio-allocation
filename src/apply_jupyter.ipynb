# %% [markdown]
# # Backtest
# Jupyter notebook to run the backtesting program (needed to show pyfolio report).
#
# This is a base and general version contaning examples from the Readme file. Please refer to the Readme file for more details on the arguments.
#
# Please save a new copy for specific analysis.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# ### 0. Tests

# %%
# %run main --shares "SPY,IWM,TLT,GLD," --shareclass "equity,equity,bond_lt,gold" --weights "0.2, 0.3, 0.1, 0.4" --initial_cash 100000 --contribution 10000 --create_report --report_name example --startdate "2019-11-01" --enddate "2020-03-30" --system windows --leverage 1

# %%
# %run main --shares "MVV,ROM,EMQQ,ICLN,UGL,DIG,UYM,UST,UBT" --shareclass "equity,equity,equity,equity,gold,commodity,commodity,bond_it,bond_lt"  --weights "0.1,0.05,0.025,0.025,0.2, 0.1, 0.1, 0.3,0.1" --benchmark "RPAR" --initial_cash 320000 --contribution 0 --create_report --report_name example --startdate "2019-11-01" --enddate "2021-03-30" --system windows --leverage 1
# Out:
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic None
# ###    --shares MVV,ROM,EMQQ,ICLN,UGL,DIG,UYM,UST,UBT
# ###    --shareclass equity,equity,equity,equity,gold,commodity,commodity,bond_it,bond_lt
# ###    --weights 0.1,0.05,0.025,0.025,0.2, 0.1, 0.1, 0.3,0.1
# ###    --indicators False
# ###    --initial_cash 320000
# ###    --contribution 0.0
# ###    --create_report True
# ###    --report_name example
# ###    --strategy None
# ###    --startdate 2019-11-01
# ###    --enddate 2021-03-30
# ###    --system windows
# ###    --leverage 1.0
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: customweights
# ###
# ...

# %%
# %run main --historic "medium" --indicators --shares GLD,COM,SP500TR,LTB,ITB --strategy rotationuniform,rotationstrat,uniform,riskparity --initial_cash 100000 --contribution 0 --create_report --report_name MyPortfolio_Medium_lev1 --startdate "1980-01-01" --enddate "2020-01-01" --system windows --leverage 1
# Out:
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic medium
# ###    --shares GLD,COM,SP500TR,LTB,ITB
# ###    --shareclass None
# ###    --weights
# ###    --indicators True
# ###    --initial_cash 100000
# ###    --contribution 0.0
# ###    --create_report True
# ###    --report_name MyPortfolio_Medium_lev1
# ###    --strategy rotationuniform,rotationstrat,uniform,riskparity
# ###    --startdate 1980-01-01
# ###    --enddate 2020-01-01
# ###    --system windows
# ###    --leverage 1.0
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: rotationuniform
# ###
# ##############################################################################
# ...

# %%
# %run main --historic "medium" --shares GLD,COM,SP500TR,LTB,ITB --strategy uniform,onlystocks,sixtyforty,riskparity --initial_cash 100000 --contribution 0 --create_report --report_name MyPortfolio_Medium_lev1 --startdate "1980-01-01" --enddate "2020-01-01" --system windows --leverage 1

# %% [markdown]
# ### 1. Historical data, uniform strategy

# %%
# %run main --historic "medium" --shares GLD,COM,SP500,LTB,ITB --strategy uniform --initial_cash 100000 --contribution 10000 --create_report --report_name example --startdate "2015-01-01" --enddate "2020-01-01" --system windows --leverage 3

# %% [markdown]
# ### 2. Historical data, custom weights

# %%
# %run main --historic  "medium" --shares GLD,COM,SP500,LTB,ITB --weights "0.2, 0.3, 0.1, 0.1, 0.3" --initial_cash 100000 --contribution 10000 --create_report --report_name example --startdate "2015-01-01" --enddate "2020-01-01" --system windows --leverage 3

# %% [markdown]
# ### 3. Automatically downloaded data, custom weights

# %%
# %run main --shares "SPY,IWM,TLT,GLD," --shareclass "equity,equity,bond_lt,gold" --weights "0.2, 0.3, 0.1, 0.4" --initial_cash 100000 --contribution 10000 --create_report --report_name example --startdate "2015-01-01" --enddate "2020-01-01" --system windows --leverage 3

# %% [markdown]
# ### 4. Automatically downloaded data, 60-40 strategy

# %%
# %run main --shares "SPY,IWM,TLT,GLD," --shareclass "equity,equity,bond_lt,gold" --strategy sixtyforty --initial_cash 100000 --contribution 10000 --create_report --report_name example --startdate "2015-01-01" --enddate "2020-01-01" --system windows --leverage 3

# %% [markdown]
# ### 5. Multiple strategies backtest

# %%
# %run main --shares "UPRO,TQQQ,UGLD,TYD,TMF,UTSL" --shareclass "equity,equity,gold,bond_it,bond_lt,commodity" --strategy riskparity_nested,riskparity,uniform,sixtyforty,onlystocks --initial_cash 100000 --contribution 10000 --create_report --report_name MyCurrentPortfolio --startdate "2019-06-01" --enddate "2020-09-29" --system windows --leverage 1
