# %% [markdown]
# # Backtest
# Jupyter notebook to run the backtesting program (needed to show pyfolio report).
#
# This is a base and general version contaning examples from the Readme file. Please refer to the Readme file for more details on the arguments.
#
# Please save a new copy for specific analysis.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# ### 0. Tests

# %%
# %run main --historic "long" --strategy uniform,onlystocks,vanillariskparity,sixtyforty --initial_cash 1000 --monthly_cash 0 --create_report --report_name example --startdate "1928-01-01" --enddate "1940-01-01" --system windows --leverage 1
# Out:
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic long
# ###    --shares SPY,TLT
# ###    --shareclass equity,bond
# ###    --weights
# ###    --indicators False
# ###    --initial_cash 1000
# ###    --monthly_cash 0.0
# ###    --create_report True
# ###    --report_name example
# ###    --strategy uniform,onlystocks,vanillariskparity,sixtyforty
# ###    --startdate 1928-01-01
# ###    --enddate 1940-01-01
# ###    --system windows
# ###    --leverage 1
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: uniform
# ###
# ##############################################################################
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Desktop\portfolio-allocation\src\main.py in <module>
#     235                 print_section_divider(strat)
#     236
# --> 237                 ThisStrat_prices, ThisStrat_returns, ThisStrat_perf_data, ThisStrat_targetweight, ThisStrat_effectiveweight = runOneStrat(strat)
#     238                 if prices.empty:
#     239                     prices = ThisStrat_prices
#
# ~\Desktop\portfolio-allocation\src\main.py in runOneStrat(strategy)
#     205         outfile = os.path.join(outputdir, args.report_name)
#     206
# --> 207         prices, returns, perf_data, targetweights, effectiveweights = cerebro.report(outfile, system=args.system)
#     208         return prices, returns, perf_data, targetweights, effectiveweights
#     209
#
# ~\Desktop\portfolio-allocation\src\report.py in report(self, outfile, user, memo, system, report_type)
#     409         bt = self.get_strategy_backtest()
#     410         rpt = PerformanceReport(bt, outfile=outfile, user=user, memo=memo, system=system)
# --> 411         rpt.generate_pdf_report()
#     412
#     413         try:
#
# ~\Desktop\portfolio-allocation\src\report.py in generate_pdf_report(self)
#     214         """ Returns PDF report with backtest results
#     215         """
# --> 216         html = self.generate_html()
#     217         outfile = self.outfile + "_" + self.get_strategy_name() + "_" + get_now() + ".pdf"
#     218         HTML(string=html).write_pdf(outfile)
#
# ~\Desktop\portfolio-allocation\src\report.py in generate_html(self)
#     160         eq_curve = os.path.join(images, 'equity_curve.png')
#     161         rt_curve = os.path.join(images, 'return_curve.png')
# --> 162         fig_equity = self.plot_equity_curve()
#     163         fig_equity.savefig(eq_curve)
#     164         fig_return = self.plot_return_curve()
#
# ~\Desktop\portfolio-allocation\src\report.py in plot_equity_curve(self, fname)
#     104         """ Plots equity curve to png file
#     105         """
# --> 106         curve = self.get_equity_curve()
#     107         xrnge = [curve.index[0], curve.index[-1]]
#     108         dotted = pd.Series(data=[100, 100], index=xrnge)
#
# ~\Desktop\portfolio-allocation\src\report.py in get_equity_curve(self)
#      74         """
#      75         st = self.stratbt
# ---> 76         dt = self.get_date_index()
#      77         value = st.observers.broker.lines[1].get(size=len(dt))
#      78         vv = np.asarray(value)
#
# ~\Desktop\portfolio-allocation\src\report.py in get_date_index(self)
#     241         df = pd.to_datetime(df[["day", "month", "year"]])
#     242         df.index = df
# --> 243         df = df[df > st.startdate]
#     244         return df.index
#     245
#
# ~\Anaconda3\envs\portfolio-allocation\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\Anaconda3\envs\portfolio-allocation\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     527         rvalues = extract_array(other, extract_numpy=True)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
#     530
#     531         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# ~\Anaconda3\envs\portfolio-allocation\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     235
#     236     if should_extension_dispatch(lvalues, rvalues):
# --> 237         res_values = dispatch_to_extension_op(op, lvalues, rvalues)
#     238
#     239     elif is_scalar(rvalues) and isna(rvalues):
#
# ~\Anaconda3\envs\portfolio-allocation\lib\site-packages\pandas\core\ops\dispatch.py in dispatch_to_extension_op(op, left, right)
#     123     # The op calls will raise TypeError if the op is not defined
#     124     # on the ExtensionArray
# --> 125     res_values = op(left, right)
#     126     return res_values
#
# ~\Anaconda3\envs\portfolio-allocation\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\Anaconda3\envs\portfolio-allocation\lib\site-packages\pandas\core\arrays\datetimelike.py in wrapper(self, other)
#      81
#      82         elif not is_list_like(other):
# ---> 83             return invalid_comparison(self, other, op)
#      84
#      85         elif len(other) != len(self):
#
# ~\Anaconda3\envs\portfolio-allocation\lib\site-packages\pandas\core\ops\invalid.py in invalid_comparison(left, right, op)
#      32     else:
#      33         typ = type(right).__name__
# ---> 34         raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      35     return res_values
#      36
#
# TypeError: Invalid comparison between dtype=datetime64[ns] and NoneType

# %% [markdown]
# ### 1. Historical data, uniform strategy

# %%
# %run main --historic "medium" --strategy uniform --initial_cash 100000 --monthly_cash 10000 --create_report --report_name example --startdate "2015-01-01" --enddate "2020-01-01" --system windows --leverage 3
# Out:
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic medium
# ###    --shares SPY,TLT
# ###    --shareclass equity,bond
# ###    --weights
# ###    --indicators False
# ###    --initial_cash 100000
# ###    --monthly_cash 10000.0
# ###    --create_report True
# ###    --report_name example
# ###    --strategy uniform
# ###    --startdate 2015-01-01
# ###    --enddate 2020-01-01
# ###    --system windows
# ###    --leverage 3
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: uniform
# ###
# ##############################################################################
# 2015-09-10, Pre-rebalancing CASH 100000.00, VALUE  100000.00, FUND SHARES 1000.00, FUND VALUE 100.00:
# 2015-09-10, BUY EXECUTED, Price: 352.61, Size: 56.00, Comm 0.00
# 2015-09-10, BUY EXECUTED, Price: 0.02, Size: 1027516.00, Comm 0.00
# 2015-09-10, BUY EXECUTED, Price: 73.22, Size: 271.00, Comm 0.00
# 2015-09-10, BUY EXECUTED, Price: 352.61, Size: 56.00, Comm 0.00
# 2015-09-10, BUY EXECUTED, Price: 11004.20, Size: 1.00, Comm 0.00
# 2015-09-10, Order Canceled/Margin/Rejected.
# 2015-09-10, Order Canceled/Margin/Rejected.
# 2015-09-10, Order Canceled/Margin/Rejected.
# 2015-09-14, BUY EXECUTED, Price: 10286.32, Size: 1.00, Comm 0.00
# 2015-09-21, MONTHLY CASH ADDED: new cash amount is 10156
# 2015-09-22, Order Canceled/Margin/Rejected.
# 2015-10-20, MONTHLY CASH ADDED: new cash amount is 20156
# 2015-10-22, Pre-rebalancing CASH 20156.47, VALUE  126613.90, FUND SHARES 1191.79, FUND VALUE 106.24:
# 2015-10-22, SELL EXECUTED, Price: 407.07, Size: -112.00, Comm 0.00
# 2015-10-22, SELL EXECUTED, Price: 9891.93, Size: -2.00, Comm 0.00
# 2015-10-22, SELL EXECUTED, Price: 0.02, Size: -1027516.00, Comm 0.00
# 2015-10-22, SELL EXECUTED, Price: 75.38, Size: -271.00, Comm 0.00
# 2015-10-22, BUY EXECUTED, Price: 407.07, Size: 62.00, Comm 0.00
# 2015-10-22, BUY EXECUTED, Price: 9891.93, Size: 2.00, Comm 0.00
# 2015-10-22, BUY EXECUTED, Price: 1633.84, Size: 15.00, Comm 0.00
# 2015-10-22, BUY EXECUTED, Price: 0.02, Size: 1241461.00, Comm 0.00
# 2015-10-22, BUY EXECUTED, Price: 75.38, Size: 336.00, Comm 0.00
# 2015-11-20, MONTHLY CASH ADDED: new cash amount is 16726
# 2015-12-03, Pre-rebalancing CASH 16726.37, VALUE  123164.70, FUND SHARES 1296.40, FUND VALUE 95.00:
# 2015-12-03, SELL EXECUTED, Price: 299.07, Size: -62.00, Comm 0.00
# 2015-12-03, SELL EXECUTED, Price: 7390.12, Size: -2.00, Comm 0.00
# 2015-12-03, SELL EXECUTED, Price: 1617.95, Size: -15.00, Comm 0.00
# 2015-12-03, SELL EXECUTED, Price: 0.02, Size: -1241461.00, Comm 0.00
# 2015-12-03, SELL EXECUTED, Price: 71.04, Size: -336.00, Comm 0.00
# 2015-12-03, BUY EXECUTED, Price: 299.07, Size: 79.00, Comm 0.00
# 2015-12-03, BUY EXECUTED, Price: 7390.12, Size: 3.00, Comm 0.00
# 2015-12-03, BUY EXECUTED, Price: 1617.95, Size: 14.00, Comm 0.00
# 2015-12-03, BUY EXECUTED, Price: 0.02, Size: 1425900.00, Comm 0.00
# 2015-12-03, BUY EXECUTED, Price: 71.04, Size: 334.00, Comm 0.00
# 2015-12-21, MONTHLY CASH ADDED: new cash amount is 12936
# 2016-01-14, Pre-rebalancing CASH 12936.48, VALUE  121656.44, FUND SHARES 1407.46, FUND VALUE 86.44:
# 2016-01-14, SELL EXECUTED, Price: 324.93, Size: -79.00, Comm 0.00
# 2016-01-14, SELL EXECUTED, Price: 4199.42, Size: -3.00, Comm 0.00
# 2016-01-14, SELL EXECUTED, Price: 1315.75, Size: -14.00, Comm 0.00
# 2016-01-14, SELL EXECUTED, Price: 0.02, Size: -1425900.00, Comm 0.00
# 2016-01-14, SELL EXECUTED, Price: 73.40, Size: -334.00, Comm 0.00
# 2016-01-14, BUY EXECUTED, Price: 324.93, Size: 74.00, Comm 0.00
# 2016-01-14, BUY EXECUTED, Price: 4199.42, Size: 5.00, Comm 0.00
# 2016-01-14, BUY EXECUTED, Price: 1315.75, Size: 18.00, Comm 0.00
# 2016-01-14, BUY EXECUTED, Price: 0.02, Size: 1262847.00, Comm 0.00
# 2016-01-14, BUY EXECUTED, Price: 73.40, Size: 331.00, Comm 0.00
# 2016-01-20, MONTHLY CASH ADDED: new cash amount is 14260
# 2016-02-22, MONTHLY CASH ADDED: new cash amount is 24260
# 2016-02-25, Pre-rebalancing CASH 24259.60, VALUE  160761.74, FUND SHARES 1627.39, FUND VALUE 98.78:
# 2016-02-25, SELL EXECUTED, Price: 467.37, Size: -74.00, Comm 0.00
# 2016-02-25, SELL EXECUTED, Price: 4230.31, Size: -5.00, Comm 0.00
# 2016-02-25, SELL EXECUTED, Price: 1358.50, Size: -18.00, Comm 0.00
# 2016-02-25, SELL EXECUTED, Price: 0.03, Size: -1262847.00, Comm 0.00
# 2016-02-25, SELL EXECUTED, Price: 77.48, Size: -331.00, Comm 0.00
# 2016-02-25, BUY EXECUTED, Price: 467.37, Size: 69.00, Comm 0.00
# 2016-02-25, BUY EXECUTED, Price: 4230.31, Size: 7.00, Comm 0.00
# 2016-02-25, BUY EXECUTED, Price: 1358.50, Size: 23.00, Comm 0.00
# 2016-02-25, BUY EXECUTED, Price: 0.03, Size: 1290428.00, Comm 0.00
# 2016-02-25, BUY EXECUTED, Price: 77.48, Size: 417.00, Comm 0.00
# 2016-03-21, MONTHLY CASH ADDED: new cash amount is 13989
# 2016-04-07, Pre-rebalancing CASH 13988.60, VALUE  178230.47, FUND SHARES 1722.45, FUND VALUE 103.47:
# 2016-04-07, SELL EXECUTED, Price: 467.99, Size: -69.00, Comm 0.00
# 2016-04-07, SELL EXECUTED, Price: 4591.90, Size: -7.00, Comm 0.00
# 2016-04-07, SELL EXECUTED, Price: 1547.75, Size: -23.00, Comm 0.00
# 2016-04-07, SELL EXECUTED, Price: 0.03, Size: -1290428.00, Comm 0.00
# 2016-04-07, SELL EXECUTED, Price: 77.57, Size: -417.00, Comm 0.00
# 2016-04-07, BUY EXECUTED, Price: 467.99, Size: 76.00, Comm 0.00
# 2016-04-07, BUY EXECUTED, Price: 4591.90, Size: 7.00, Comm 0.00
# 2016-04-07, BUY EXECUTED, Price: 1547.75, Size: 23.00, Comm 0.00
# 2016-04-07, BUY EXECUTED, Price: 0.03, Size: 1382375.00, Comm 0.00
# 2016-04-07, BUY EXECUTED, Price: 77.57, Size: 464.00, Comm 0.00
# 2016-04-20, MONTHLY CASH ADDED: new cash amount is 14673
# 2016-05-19, Pre-rebalancing CASH 14672.79, VALUE  201795.40, FUND SHARES 1813.41, FUND VALUE 111.28:
# 2016-05-19, SELL EXECUTED, Price: 468.79, Size: -76.00, Comm 0.00
# 2016-05-19, SELL EXECUTED, Price: 6693.78, Size: -7.00, Comm 0.00
# 2016-05-19, SELL EXECUTED, Price: 1538.39, Size: -23.00, Comm 0.00
# 2016-05-19, SELL EXECUTED, Price: 0.02, Size: -1382375.00, Comm 0.00
# 2016-05-19, SELL EXECUTED, Price: 74.91, Size: -464.00, Comm 0.00
# 2016-05-19, BUY EXECUTED, Price: 468.79, Size: 85.00, Comm 0.00
# 2016-05-19, BUY EXECUTED, Price: 6693.78, Size: 5.00, Comm 0.00
# 2016-05-19, BUY EXECUTED, Price: 1538.39, Size: 25.00, Comm 0.00
# 2016-05-19, BUY EXECUTED, Price: 0.02, Size: 1719761.00, Comm 0.00
# 2016-05-19, BUY EXECUTED, Price: 74.91, Size: 532.00, Comm 0.00
# 2016-05-20, MONTHLY CASH ADDED: new cash amount is 17849
# 2016-06-20, MONTHLY CASH ADDED: new cash amount is 27849
# 2016-06-30, Pre-rebalancing CASH 27848.81, VALUE  246117.19, FUND SHARES 1988.14, FUND VALUE 123.79:
# 2016-06-30, SELL EXECUTED, Price: 551.31, Size: -85.00, Comm 0.00
# 2016-06-30, SELL EXECUTED, Price: 6824.68, Size: -5.00, Comm 0.00
# 2016-06-30, SELL EXECUTED, Price: 1658.99, Size: -25.00, Comm 0.00
# 2016-06-30, SELL EXECUTED, Price: 0.03, Size: -1719761.00, Comm 0.00
# 2016-06-30, SELL EXECUTED, Price: 79.00, Size: -532.00, Comm 0.00
# 2016-06-30, BUY EXECUTED, Price: 551.31, Size: 88.00, Comm 0.00
# 2016-06-30, BUY EXECUTED, Price: 6824.68, Size: 7.00, Comm 0.00
# 2016-06-30, BUY EXECUTED, Price: 1658.99, Size: 29.00, Comm 0.00
# 2016-06-30, BUY EXECUTED, Price: 0.03, Size: 1607455.00, Comm 0.00
# 2016-06-30, BUY EXECUTED, Price: 79.00, Size: 619.00, Comm 0.00
# 2016-07-20, MONTHLY CASH ADDED: new cash amount is 12456
# 2016-08-11, Pre-rebalancing CASH 12455.79, VALUE  252204.14, FUND SHARES 2070.81, FUND VALUE 121.79:
# 2016-08-11, SELL EXECUTED, Price: 592.24, Size: -88.00, Comm 0.00
# 2016-08-11, SELL EXECUTED, Price: 5290.84, Size: -7.00, Comm 0.00
# 2016-08-11, SELL EXECUTED, Price: 1870.27, Size: -29.00, Comm 0.00
# 2016-08-11, SELL EXECUTED, Price: 0.03, Size: -1607455.00, Comm 0.00
# 2016-08-11, SELL EXECUTED, Price: 77.35, Size: -619.00, Comm 0.00
# 2016-08-11, BUY EXECUTED, Price: 592.24, Size: 85.00, Comm 0.00
# 2016-08-11, BUY EXECUTED, Price: 5290.84, Size: 9.00, Comm 0.00
# 2016-08-11, BUY EXECUTED, Price: 1870.27, Size: 27.00, Comm 0.00
# 2016-08-11, BUY EXECUTED, Price: 0.03, Size: 1653885.00, Comm 0.00
# 2016-08-11, BUY EXECUTED, Price: 77.35, Size: 653.00, Comm 0.00
# 2016-08-22, MONTHLY CASH ADDED: new cash amount is 13342
# 2016-09-20, MONTHLY CASH ADDED: new cash amount is 23342
# 2016-09-22, Pre-rebalancing CASH 23341.73, VALUE  262907.63, FUND SHARES 2237.88, FUND VALUE 117.48:
# 2016-09-22, SELL EXECUTED, Price: 569.77, Size: -85.00, Comm 0.00
# 2016-09-22, SELL EXECUTED, Price: 5553.47, Size: -9.00, Comm 0.00
# 2016-09-22, SELL EXECUTED, Price: 1839.94, Size: -27.00, Comm 0.00
# 2016-09-22, SELL EXECUTED, Price: 0.03, Size: -1653885.00, Comm 0.00
# 2016-09-22, SELL EXECUTED, Price: 77.06, Size: -653.00, Comm 0.00
# 2016-09-22, BUY EXECUTED, Price: 569.77, Size: 94.00, Comm 0.00
# 2016-09-22, BUY EXECUTED, Price: 5553.47, Size: 9.00, Comm 0.00
# 2016-09-22, BUY EXECUTED, Price: 1839.94, Size: 29.00, Comm 0.00
# 2016-09-22, BUY EXECUTED, Price: 0.03, Size: 1888914.00, Comm 0.00
# 2016-09-22, BUY EXECUTED, Price: 77.06, Size: 697.00, Comm 0.00
# 2016-10-20, MONTHLY CASH ADDED: new cash amount is 14453
# 2016-11-03, Pre-rebalancing CASH 14453.39, VALUE  255453.05, FUND SHARES 2325.31, FUND VALUE 109.86:
# 2016-11-03, SELL EXECUTED, Price: 520.03, Size: -94.00, Comm 0.00
# 2016-11-03, SELL EXECUTED, Price: 5081.56, Size: -9.00, Comm 0.00
# 2016-11-03, SELL EXECUTED, Price: 1620.58, Size: -29.00, Comm 0.00
# 2016-11-03, SELL EXECUTED, Price: 0.02, Size: -1888914.00, Comm 0.00
# 2016-11-03, SELL EXECUTED, Price: 76.04, Size: -697.00, Comm 0.00
# 2016-11-03, BUY EXECUTED, Price: 520.03, Size: 96.00, Comm 0.00
# 2016-11-03, BUY EXECUTED, Price: 5081.56, Size: 9.00, Comm 0.00
# 2016-11-03, BUY EXECUTED, Price: 1620.58, Size: 31.00, Comm 0.00
# 2016-11-03, BUY EXECUTED, Price: 0.02, Size: 2216549.00, Comm 0.00
# 2016-11-03, BUY EXECUTED, Price: 76.04, Size: 662.00, Comm 0.00
# 2016-11-21, MONTHLY CASH ADDED: new cash amount is 15383
# 2016-12-15, Pre-rebalancing CASH 15383.18, VALUE  245801.55, FUND SHARES 2424.16, FUND VALUE 101.40:
# 2016-12-15, SELL EXECUTED, Price: 334.14, Size: -96.00, Comm 0.00
# 2016-12-15, SELL EXECUTED, Price: 6223.53, Size: -9.00, Comm 0.00
# 2016-12-15, SELL EXECUTED, Price: 2051.19, Size: -31.00, Comm 0.00
# 2016-12-15, SELL EXECUTED, Price: 0.01, Size: -2216549.00, Comm 0.00
# 2016-12-15, SELL EXECUTED, Price: 67.49, Size: -662.00, Comm 0.00
# 2016-12-15, BUY EXECUTED, Price: 334.14, Size: 144.00, Comm 0.00
# 2016-12-15, BUY EXECUTED, Price: 6223.53, Size: 7.00, Comm 0.00
# 2016-12-15, BUY EXECUTED, Price: 2051.19, Size: 23.00, Comm 0.00
# 2016-12-15, BUY EXECUTED, Price: 0.01, Size: 3533533.00, Comm 0.00
# 2016-12-15, BUY EXECUTED, Price: 67.49, Size: 717.00, Comm 0.00
# 2016-12-20, MONTHLY CASH ADDED: new cash amount is 16442
# 2017-01-20, MONTHLY CASH ADDED: new cash amount is 26442
# 2017-01-26, Pre-rebalancing CASH 26441.89, VALUE  276413.56, FUND SHARES 2617.50, FUND VALUE 105.60:
# 2017-01-26, SELL EXECUTED, Price: 390.37, Size: -144.00, Comm 0.00
# 2017-01-26, SELL EXECUTED, Price: 6579.97, Size: -7.00, Comm 0.00
# 2017-01-26, SELL EXECUTED, Price: 2144.18, Size: -23.00, Comm 0.00
# 2017-01-26, SELL EXECUTED, Price: 0.01, Size: -3533533.00, Comm 0.00
# 2017-01-26, SELL EXECUTED, Price: 68.52, Size: -717.00, Comm 0.00
# 2017-01-26, BUY EXECUTED, Price: 390.37, Size: 142.00, Comm 0.00
# 2017-01-26, BUY EXECUTED, Price: 6579.97, Size: 8.00, Comm 0.00
# 2017-01-26, BUY EXECUTED, Price: 2144.18, Size: 25.00, Comm 0.00
# 2017-01-26, BUY EXECUTED, Price: 0.01, Size: 3902008.00, Comm 0.00
# 2017-01-26, BUY EXECUTED, Price: 68.52, Size: 809.00, Comm 0.00
# 2017-02-20, MONTHLY CASH ADDED: new cash amount is 14811
# 2017-03-09, Pre-rebalancing CASH 14811.06, VALUE  283028.24, FUND SHARES 2707.84, FUND VALUE 104.52:
# 2017-03-09, SELL EXECUTED, Price: 405.12, Size: -142.00, Comm 0.00
# 2017-03-09, SELL EXECUTED, Price: 5411.04, Size: -8.00, Comm 0.00
# 2017-03-09, SELL EXECUTED, Price: 2337.39, Size: -25.00, Comm 0.00
# 2017-03-09, SELL EXECUTED, Price: 0.01, Size: -3902008.00, Comm 0.00
# 2017-03-09, SELL EXECUTED, Price: 66.88, Size: -809.00, Comm 0.00
# 2017-03-09, BUY EXECUTED, Price: 405.12, Size: 137.00, Comm 0.00
# 2017-03-09, BUY EXECUTED, Price: 5411.04, Size: 10.00, Comm 0.00
# 2017-03-09, BUY EXECUTED, Price: 2337.39, Size: 23.00, Comm 0.00
# 2017-03-09, BUY EXECUTED, Price: 0.01, Size: 4292958.00, Comm 0.00
# 2017-03-09, BUY EXECUTED, Price: 66.88, Size: 833.00, Comm 0.00
# 2017-03-20, MONTHLY CASH ADDED: new cash amount is 14005
# 2017-04-20, Pre-rebalancing CASH 14005.37, VALUE  319163.05, FUND SHARES 2801.82, FUND VALUE 113.91:
# 2017-04-20, MONTHLY CASH ADDED: new cash amount is 15145
# 2017-04-20, SELL EXECUTED, Price: 483.56, Size: -137.00, Comm 0.00
# 2017-04-20, SELL EXECUTED, Price: 5460.07, Size: -10.00, Comm 0.00
# 2017-04-20, SELL EXECUTED, Price: 2306.89, Size: -23.00, Comm 0.00
# 2017-04-20, SELL EXECUTED, Price: 0.02, Size: -4292958.00, Comm 0.00
# 2017-04-20, SELL EXECUTED, Price: 70.42, Size: -833.00, Comm 0.00
# 2017-04-20, BUY EXECUTED, Price: 483.56, Size: 131.00, Comm 0.00
# 2017-04-20, BUY EXECUTED, Price: 5460.07, Size: 11.00, Comm 0.00
# 2017-04-20, BUY EXECUTED, Price: 2306.89, Size: 27.00, Comm 0.00
# 2017-04-20, BUY EXECUTED, Price: 0.02, Size: 3821047.00, Comm 0.00
# 2017-04-20, BUY EXECUTED, Price: 70.42, Size: 903.00, Comm 0.00
# 2017-05-22, MONTHLY CASH ADDED: new cash amount is 25145
# 2017-06-01, Pre-rebalancing CASH 25145.29, VALUE  336238.04, FUND SHARES 2978.19, FUND VALUE 112.90:
# 2017-06-01, SELL EXECUTED, Price: 462.77, Size: -131.00, Comm 0.00
# 2017-06-01, SELL EXECUTED, Price: 4953.65, Size: -11.00, Comm 0.00
# 2017-06-01, SELL EXECUTED, Price: 2526.26, Size: -27.00, Comm 0.00
# 2017-06-01, SELL EXECUTED, Price: 0.02, Size: -3821047.00, Comm 0.00
# 2017-06-01, SELL EXECUTED, Price: 70.48, Size: -903.00, Comm 0.00
# 2017-06-01, BUY EXECUTED, Price: 462.77, Size: 145.00, Comm 0.00
# 2017-06-01, BUY EXECUTED, Price: 4953.65, Size: 13.00, Comm 0.00
# 2017-06-01, BUY EXECUTED, Price: 2526.26, Size: 26.00, Comm 0.00
# 2017-06-01, BUY EXECUTED, Price: 0.02, Size: 3995849.00, Comm 0.00
# 2017-06-01, BUY EXECUTED, Price: 70.48, Size: 954.00, Comm 0.00
# 2017-06-20, MONTHLY CASH ADDED: new cash amount is 14747
# 2017-07-13, Pre-rebalancing CASH 14747.38, VALUE  332372.89, FUND SHARES 3068.28, FUND VALUE 108.33:
# 2017-07-13, SELL EXECUTED, Price: 412.49, Size: -145.00, Comm 0.00
# 2017-07-13, SELL EXECUTED, Price: 4604.46, Size: -13.00, Comm 0.00
# 2017-07-13, SELL EXECUTED, Price: 2577.56, Size: -26.00, Comm 0.00
# 2017-07-13, SELL EXECUTED, Price: 0.02, Size: -3995849.00, Comm 0.00
# 2017-07-13, SELL EXECUTED, Price: 69.17, Size: -954.00, Comm 0.00
# 2017-07-13, BUY EXECUTED, Price: 412.49, Size: 160.00, Comm 0.00
# 2017-07-13, BUY EXECUTED, Price: 4604.46, Size: 14.00, Comm 0.00
# 2017-07-13, BUY EXECUTED, Price: 2577.56, Size: 25.00, Comm 0.00
# 2017-07-13, BUY EXECUTED, Price: 0.02, Size: 4148520.00, Comm 0.00
# 2017-07-13, BUY EXECUTED, Price: 69.17, Size: 957.00, Comm 0.00
# 2017-07-20, MONTHLY CASH ADDED: new cash amount is 13888
# 2017-08-21, MONTHLY CASH ADDED: new cash amount is 23888
# 2017-08-24, Pre-rebalancing CASH 23887.67, VALUE  378332.37, FUND SHARES 3243.37, FUND VALUE 116.65:
# 2017-08-24, SELL EXECUTED, Price: 486.46, Size: -160.00, Comm 0.00
# 2017-08-24, SELL EXECUTED, Price: 4880.03, Size: -14.00, Comm 0.00
# 2017-08-24, SELL EXECUTED, Price: 2543.77, Size: -25.00, Comm 0.00
# 2017-08-24, SELL EXECUTED, Price: 0.02, Size: -4148520.00, Comm 0.00
# 2017-08-24, SELL EXECUTED, Price: 70.35, Size: -957.00, Comm 0.00
# 2017-08-24, BUY EXECUTED, Price: 486.46, Size: 154.00, Comm 0.00
# 2017-08-24, BUY EXECUTED, Price: 4880.03, Size: 15.00, Comm 0.00
# 2017-08-24, BUY EXECUTED, Price: 2543.77, Size: 29.00, Comm 0.00
# 2017-08-24, BUY EXECUTED, Price: 0.02, Size: 4148665.00, Comm 0.00
# 2017-08-24, BUY EXECUTED, Price: 70.35, Size: 1069.00, Comm 0.00
# 2017-09-20, MONTHLY CASH ADDED: new cash amount is 13870
# 2017-10-05, Pre-rebalancing CASH 13869.72, VALUE  391799.83, FUND SHARES 3325.95, FUND VALUE 117.80:
# 2017-10-05, SELL EXECUTED, Price: 468.01, Size: -154.00, Comm 0.00
# 2017-10-05, SELL EXECUTED, Price: 5633.39, Size: -15.00, Comm 0.00
# 2017-10-05, SELL EXECUTED, Price: 2911.13, Size: -29.00, Comm 0.00
# 2017-10-05, SELL EXECUTED, Price: 0.02, Size: -4148665.00, Comm 0.00
# 2017-10-05, SELL EXECUTED, Price: 68.56, Size: -1069.00, Comm 0.00
# 2017-10-05, BUY EXECUTED, Price: 468.01, Size: 168.00, Comm 0.00
# 2017-10-05, BUY EXECUTED, Price: 5633.39, Size: 14.00, Comm 0.00
# 2017-10-05, BUY EXECUTED, Price: 2911.13, Size: 27.00, Comm 0.00
# 2017-10-05, BUY EXECUTED, Price: 0.02, Size: 4895152.00, Comm 0.00
# 2017-10-05, BUY EXECUTED, Price: 68.56, Size: 1152.00, Comm 0.00
# 2017-10-20, MONTHLY CASH ADDED: new cash amount is 11031
# 2017-11-16, Pre-rebalancing CASH 11031.25, VALUE  424333.05, FUND SHARES 3409.35, FUND VALUE 124.46:
# 2017-11-16, SELL EXECUTED, Price: 472.62, Size: -168.00, Comm 0.00
# 2017-11-16, SELL EXECUTED, Price: 6296.06, Size: -14.00, Comm 0.00
# 2017-11-16, SELL EXECUTED, Price: 3024.82, Size: -27.00, Comm 0.00
# 2017-11-16, SELL EXECUTED, Price: 0.02, Size: -4895152.00, Comm 0.00
# 2017-11-16, SELL EXECUTED, Price: 67.38, Size: -1152.00, Comm 0.00
# 2017-11-16, BUY EXECUTED, Price: 472.62, Size: 178.00, Comm 0.00
# 2017-11-16, BUY EXECUTED, Price: 6296.06, Size: 13.00, Comm 0.00
# 2017-11-16, BUY EXECUTED, Price: 3024.82, Size: 27.00, Comm 0.00
# 2017-11-16, BUY EXECUTED, Price: 0.02, Size: 4887753.00, Comm 0.00
# 2017-11-16, BUY EXECUTED, Price: 67.38, Size: 1254.00, Comm 0.00
# 2017-11-20, MONTHLY CASH ADDED: new cash amount is 15856
# 2017-12-20, MONTHLY CASH ADDED: new cash amount is 25856
# 2017-12-28, Pre-rebalancing CASH 25855.77, VALUE  465029.03, FUND SHARES 3569.54, FUND VALUE 130.28:
# 2017-12-28, SELL EXECUTED, Price: 484.12, Size: -178.00, Comm 0.00
# 2017-12-28, SELL EXECUTED, Price: 7290.23, Size: -13.00, Comm 0.00
# 2017-12-28, SELL EXECUTED, Price: 3392.34, Size: -27.00, Comm 0.00
# 2017-12-28, SELL EXECUTED, Price: 0.02, Size: -4887753.00, Comm 0.00
# 2017-12-28, SELL EXECUTED, Price: 65.72, Size: -1254.00, Comm 0.00
# 2017-12-28, BUY EXECUTED, Price: 484.12, Size: 193.00, Comm 0.00
# 2017-12-28, BUY EXECUTED, Price: 7290.23, Size: 12.00, Comm 0.00
# 2017-12-28, BUY EXECUTED, Price: 3392.34, Size: 27.00, Comm 0.00
# 2017-12-28, BUY EXECUTED, Price: 0.02, Size: 5234178.00, Comm 0.00
# 2017-12-28, BUY EXECUTED, Price: 65.72, Size: 1424.00, Comm 0.00
# 2018-01-22, MONTHLY CASH ADDED: new cash amount is 18513
# 2018-02-08, Pre-rebalancing CASH 18513.09, VALUE  453649.88, FUND SHARES 3643.21, FUND VALUE 124.52:
# 2018-02-08, SELL EXECUTED, Price: 510.80, Size: -193.00, Comm 0.00
# 2018-02-08, SELL EXECUTED, Price: 7176.82, Size: -12.00, Comm 0.00
# 2018-02-08, SELL EXECUTED, Price: 2959.65, Size: -27.00, Comm 0.00
# 2018-02-08, SELL EXECUTED, Price: 0.01, Size: -5234178.00, Comm 0.00
# 2018-02-08, SELL EXECUTED, Price: 62.57, Size: -1424.00, Comm 0.00
# 2018-02-08, BUY EXECUTED, Price: 510.80, Size: 171.00, Comm 0.00
# 2018-02-08, BUY EXECUTED, Price: 7176.82, Size: 12.00, Comm 0.00
# 2018-02-08, BUY EXECUTED, Price: 2959.65, Size: 29.00, Comm 0.00
# 2018-02-08, BUY EXECUTED, Price: 0.01, Size: 6921269.00, Comm 0.00
# 2018-02-08, BUY EXECUTED, Price: 62.57, Size: 1401.00, Comm 0.00
# 2018-02-20, MONTHLY CASH ADDED: new cash amount is 13890
# 2018-03-20, MONTHLY CASH ADDED: new cash amount is 23890
# 2018-03-22, Pre-rebalancing CASH 23890.20, VALUE  478856.77, FUND SHARES 3802.97, FUND VALUE 125.92:
# 2018-03-22, SELL EXECUTED, Price: 525.52, Size: -171.00, Comm 0.00
# 2018-03-22, SELL EXECUTED, Price: 7672.53, Size: -12.00, Comm 0.00
# 2018-03-22, SELL EXECUTED, Price: 3151.34, Size: -29.00, Comm 0.00
# 2018-03-22, SELL EXECUTED, Price: 0.01, Size: -6921269.00, Comm 0.00
# 2018-03-22, SELL EXECUTED, Price: 61.97, Size: -1401.00, Comm 0.00
# 2018-03-22, BUY EXECUTED, Price: 525.52, Size: 181.00, Comm 0.00
# 2018-03-22, BUY EXECUTED, Price: 7672.53, Size: 12.00, Comm 0.00
# 2018-03-22, BUY EXECUTED, Price: 3151.34, Size: 30.00, Comm 0.00
# 2018-03-22, BUY EXECUTED, Price: 0.01, Size: 7135428.00, Comm 0.00
# 2018-03-22, BUY EXECUTED, Price: 61.97, Size: 1537.00, Comm 0.00
# 2018-04-20, MONTHLY CASH ADDED: new cash amount is 14195
# 2018-05-03, Pre-rebalancing CASH 14195.40, VALUE  484298.78, FUND SHARES 3881.30, FUND VALUE 124.78:
# 2018-05-03, SELL EXECUTED, Price: 507.36, Size: -181.00, Comm 0.00
# 2018-05-03, SELL EXECUTED, Price: 8915.76, Size: -12.00, Comm 0.00
# 2018-05-03, SELL EXECUTED, Price: 3063.54, Size: -30.00, Comm 0.00
# 2018-05-03, SELL EXECUTED, Price: 0.01, Size: -7135428.00, Comm 0.00
# 2018-05-03, SELL EXECUTED, Price: 60.62, Size: -1537.00, Comm 0.00
# 2018-05-03, BUY EXECUTED, Price: 507.36, Size: 192.00, Comm 0.00
# 2018-05-03, BUY EXECUTED, Price: 8915.76, Size: 10.00, Comm 0.00
# 2018-05-03, BUY EXECUTED, Price: 3063.54, Size: 31.00, Comm 0.00
# 2018-05-03, BUY EXECUTED, Price: 0.01, Size: 7712195.00, Comm 0.00
# 2018-05-03, BUY EXECUTED, Price: 60.62, Size: 1611.00, Comm 0.00
# 2018-05-21, MONTHLY CASH ADDED: new cash amount is 21590
# 2018-06-14, Pre-rebalancing CASH 21590.32, VALUE  512457.81, FUND SHARES 3959.49, FUND VALUE 129.43:
# 2018-06-14, SELL EXECUTED, Price: 491.96, Size: -192.00, Comm 0.00
# 2018-06-14, SELL EXECUTED, Price: 8923.18, Size: -10.00, Comm 0.00
# 2018-06-14, SELL EXECUTED, Price: 3617.16, Size: -31.00, Comm 0.00
# 2018-06-14, SELL EXECUTED, Price: 0.01, Size: -7712195.00, Comm 0.00
# 2018-06-14, SELL EXECUTED, Price: 60.29, Size: -1611.00, Comm 0.00
# 2018-06-14, BUY EXECUTED, Price: 491.96, Size: 209.00, Comm 0.00
# 2018-06-14, BUY EXECUTED, Price: 8923.18, Size: 11.00, Comm 0.00
# 2018-06-14, BUY EXECUTED, Price: 3617.16, Size: 28.00, Comm 0.00
# 2018-06-14, BUY EXECUTED, Price: 0.01, Size: 7858205.00, Comm 0.00
# 2018-06-14, BUY EXECUTED, Price: 60.29, Size: 1711.00, Comm 0.00
# 2018-06-20, MONTHLY CASH ADDED: new cash amount is 17210
# 2018-07-20, MONTHLY CASH ADDED: new cash amount is 27210
# 2018-07-26, Pre-rebalancing CASH 27209.96, VALUE  522605.46, FUND SHARES 4118.18, FUND VALUE 126.90:
# 2018-07-26, SELL EXECUTED, Price: 411.43, Size: -209.00, Comm 0.00
# 2018-07-26, SELL EXECUTED, Price: 8699.76, Size: -11.00, Comm 0.00
# 2018-07-26, SELL EXECUTED, Price: 3825.03, Size: -28.00, Comm 0.00
# 2018-07-26, SELL EXECUTED, Price: 0.01, Size: -7858205.00, Comm 0.00
# 2018-07-26, SELL EXECUTED, Price: 59.91, Size: -1711.00, Comm 0.00
# 2018-07-26, BUY EXECUTED, Price: 411.43, Size: 251.00, Comm 0.00
# 2018-07-26, BUY EXECUTED, Price: 8699.76, Size: 11.00, Comm 0.00
# 2018-07-26, BUY EXECUTED, Price: 3825.03, Size: 27.00, Comm 0.00
# 2018-07-26, BUY EXECUTED, Price: 0.01, Size: 8173940.00, Comm 0.00
# 2018-07-26, BUY EXECUTED, Price: 59.91, Size: 1729.00, Comm 0.00
# 2018-08-20, MONTHLY CASH ADDED: new cash amount is 18674
# 2018-09-06, Pre-rebalancing CASH 18673.71, VALUE  526814.74, FUND SHARES 4198.33, FUND VALUE 125.48:
# 2018-09-06, SELL EXECUTED, Price: 387.62, Size: -251.00, Comm 0.00
# 2018-09-06, SELL EXECUTED, Price: 8324.13, Size: -11.00, Comm 0.00
# 2018-09-06, SELL EXECUTED, Price: 3984.52, Size: -27.00, Comm 0.00
# 2018-09-06, SELL EXECUTED, Price: 0.01, Size: -8173940.00, Comm 0.00
# 2018-09-06, SELL EXECUTED, Price: 60.87, Size: -1729.00, Comm 0.00
# 2018-09-06, BUY EXECUTED, Price: 387.62, Size: 272.00, Comm 0.00
# 2018-09-06, BUY EXECUTED, Price: 8324.13, Size: 12.00, Comm 0.00
# 2018-09-06, BUY EXECUTED, Price: 3984.52, Size: 26.00, Comm 0.00
# 2018-09-06, BUY EXECUTED, Price: 0.01, Size: 8041684.00, Comm 0.00
# 2018-09-06, BUY EXECUTED, Price: 60.87, Size: 1733.00, Comm 0.00
# 2018-09-20, MONTHLY CASH ADDED: new cash amount is 17686
# 2018-10-18, Pre-rebalancing CASH 17686.04, VALUE  519264.52, FUND SHARES 4278.37, FUND VALUE 121.37:
# 2018-10-18, SELL EXECUTED, Price: 403.50, Size: -272.00, Comm 0.00
# 2018-10-18, SELL EXECUTED, Price: 9080.43, Size: -12.00, Comm 0.00
# 2018-10-18, SELL EXECUTED, Price: 3517.68, Size: -26.00, Comm 0.00
# 2018-10-18, SELL EXECUTED, Price: 0.01, Size: -8041684.00, Comm 0.00
# 2018-10-18, SELL EXECUTED, Price: 58.46, Size: -1733.00, Comm 0.00
# 2018-10-18, BUY EXECUTED, Price: 403.50, Size: 252.00, Comm 0.00
# 2018-10-18, BUY EXECUTED, Price: 9080.43, Size: 11.00, Comm 0.00
# 2018-10-18, BUY EXECUTED, Price: 3517.68, Size: 28.00, Comm 0.00
# 2018-10-18, BUY EXECUTED, Price: 0.01, Size: 10236091.00, Comm 0.00
# 2018-10-18, BUY EXECUTED, Price: 58.46, Size: 1742.00, Comm 0.00
# 2018-10-22, MONTHLY CASH ADDED: new cash amount is 15444
# 2018-11-20, MONTHLY CASH ADDED: new cash amount is 25444
# 2018-11-29, Pre-rebalancing CASH 25443.72, VALUE  487971.74, FUND SHARES 4453.81, FUND VALUE 109.56:
# 2018-11-29, SELL EXECUTED, Price: 405.65, Size: -252.00, Comm 0.00
# 2018-11-29, SELL EXECUTED, Price: 5658.63, Size: -11.00, Comm 0.00
# 2018-11-29, SELL EXECUTED, Price: 3351.49, Size: -28.00, Comm 0.00
# 2018-11-29, SELL EXECUTED, Price: 0.01, Size: -10236091.00, Comm 0.00
# 2018-11-29, SELL EXECUTED, Price: 59.90, Size: -1742.00, Comm 0.00
# 2018-11-29, BUY EXECUTED, Price: 405.65, Size: 242.00, Comm 0.00
# 2018-11-29, BUY EXECUTED, Price: 5658.63, Size: 17.00, Comm 0.00
# 2018-11-29, BUY EXECUTED, Price: 3351.49, Size: 29.00, Comm 0.00
# 2018-11-29, BUY EXECUTED, Price: 0.01, Size: 9669426.00, Comm 0.00
# 2018-11-29, BUY EXECUTED, Price: 59.90, Size: 1643.00, Comm 0.00
# 2018-12-20, MONTHLY CASH ADDED: new cash amount is 13898
# 2019-01-10, Pre-rebalancing CASH 13897.85, VALUE  529490.27, FUND SHARES 4544.88, FUND VALUE 116.50:
# 2019-01-10, SELL EXECUTED, Price: 473.19, Size: -242.00, Comm 0.00
# 2019-01-10, SELL EXECUTED, Price: 5444.23, Size: -17.00, Comm 0.00
# 2019-01-10, SELL EXECUTED, Price: 2785.22, Size: -29.00, Comm 0.00
# 2019-01-10, SELL EXECUTED, Price: 0.01, Size: -9669426.00, Comm 0.00
# 2019-01-10, SELL EXECUTED, Price: 62.52, Size: -1643.00, Comm 0.00
# 2019-01-10, BUY EXECUTED, Price: 473.19, Size: 223.00, Comm 0.00
# 2019-01-10, BUY EXECUTED, Price: 5444.23, Size: 19.00, Comm 0.00
# 2019-01-10, BUY EXECUTED, Price: 2785.22, Size: 37.00, Comm 0.00
# 2019-01-10, BUY EXECUTED, Price: 0.01, Size: 8231401.00, Comm 0.00
# 2019-01-10, BUY EXECUTED, Price: 62.52, Size: 1691.00, Comm 0.00
# 2019-01-21, MONTHLY CASH ADDED: new cash amount is 15188
# 2019-02-20, MONTHLY CASH ADDED: new cash amount is 25188
# 2019-02-21, Pre-rebalancing CASH 25188.49, VALUE  594734.89, FUND SHARES 4707.68, FUND VALUE 128.46:
# 2019-02-21, SELL EXECUTED, Price: 516.81, Size: -223.00, Comm 0.00
# 2019-02-21, SELL EXECUTED, Price: 6222.66, Size: -19.00, Comm 0.00
# 2019-02-21, SELL EXECUTED, Price: 3383.81, Size: -37.00, Comm 0.00
# 2019-02-21, SELL EXECUTED, Price: 0.01, Size: -8231401.00, Comm 0.00
# 2019-02-21, SELL EXECUTED, Price: 62.98, Size: -1691.00, Comm 0.00
# 2019-02-21, BUY EXECUTED, Price: 516.81, Size: 230.00, Comm 0.00
# 2019-02-21, BUY EXECUTED, Price: 6222.66, Size: 19.00, Comm 0.00
# 2019-02-21, BUY EXECUTED, Price: 3383.81, Size: 35.00, Comm 0.00
# 2019-02-21, BUY EXECUTED, Price: 0.01, Size: 9274389.00, Comm 0.00
# 2019-02-21, BUY EXECUTED, Price: 62.98, Size: 1893.00, Comm 0.00
# 2019-03-20, MONTHLY CASH ADDED: new cash amount is 12208
# 2019-04-04, Pre-rebalancing CASH 12207.87, VALUE  634716.97, FUND SHARES 4784.46, FUND VALUE 132.66:
# 2019-04-04, SELL EXECUTED, Price: 461.34, Size: -230.00, Comm 0.00
# 2019-04-04, SELL EXECUTED, Price: 6876.71, Size: -19.00, Comm 0.00
# 2019-04-04, SELL EXECUTED, Price: 3765.98, Size: -35.00, Comm 0.00
# 2019-04-04, SELL EXECUTED, Price: 0.01, Size: -9274389.00, Comm 0.00
# 2019-04-04, SELL EXECUTED, Price: 64.74, Size: -1893.00, Comm 0.00
# 2019-04-04, BUY EXECUTED, Price: 461.34, Size: 275.00, Comm 0.00
# 2019-04-04, BUY EXECUTED, Price: 6876.71, Size: 18.00, Comm 0.00
# 2019-04-04, BUY EXECUTED, Price: 3765.98, Size: 33.00, Comm 0.00
# 2019-04-04, BUY EXECUTED, Price: 0.01, Size: 8948384.00, Comm 0.00
# 2019-04-04, BUY EXECUTED, Price: 64.74, Size: 1961.00, Comm 0.00
# 2019-04-22, MONTHLY CASH ADDED: new cash amount is 16080
# 2019-05-16, Pre-rebalancing CASH 16080.34, VALUE  656501.48, FUND SHARES 4859.55, FUND VALUE 135.10:
# 2019-05-16, SELL EXECUTED, Price: 469.75, Size: -275.00, Comm 0.00
# 2019-05-16, SELL EXECUTED, Price: 6975.97, Size: -18.00, Comm 0.00
# 2019-05-16, SELL EXECUTED, Price: 3737.00, Size: -33.00, Comm 0.00
# 2019-05-16, SELL EXECUTED, Price: 0.02, Size: -8948384.00, Comm 0.00
# 2019-05-16, SELL EXECUTED, Price: 65.98, Size: -1961.00, Comm 0.00
# 2019-05-16, BUY EXECUTED, Price: 469.75, Size: 280.00, Comm 0.00
# 2019-05-16, BUY EXECUTED, Price: 6975.97, Size: 18.00, Comm 0.00
# 2019-05-16, BUY EXECUTED, Price: 3737.00, Size: 35.00, Comm 0.00
# 2019-05-16, BUY EXECUTED, Price: 0.02, Size: 8688251.00, Comm 0.00
# 2019-05-16, BUY EXECUTED, Price: 65.98, Size: 1998.00, Comm 0.00
# 2019-05-20, MONTHLY CASH ADDED: new cash amount is 17765
# 2019-06-20, MONTHLY CASH ADDED: new cash amount is 27765
# 2019-06-27, Pre-rebalancing CASH 27764.59, VALUE  748979.44, FUND SHARES 5001.53, FUND VALUE 149.75:
# 2019-06-27, SELL EXECUTED, Price: 596.70, Size: -280.00, Comm 0.00
# 2019-06-27, SELL EXECUTED, Price: 6242.64, Size: -18.00, Comm 0.00
# 2019-06-27, SELL EXECUTED, Price: 3910.68, Size: -35.00, Comm 0.00
# 2019-06-27, SELL EXECUTED, Price: 0.02, Size: -8688251.00, Comm 0.00
# 2019-06-27, SELL EXECUTED, Price: 70.19, Size: -1998.00, Comm 0.00
# 2019-06-27, BUY EXECUTED, Price: 596.70, Size: 253.00, Comm 0.00
# 2019-06-27, BUY EXECUTED, Price: 6242.64, Size: 24.00, Comm 0.00
# 2019-06-27, BUY EXECUTED, Price: 3910.68, Size: 38.00, Comm 0.00
# 2019-06-27, BUY EXECUTED, Price: 0.02, Size: 7633023.00, Comm 0.00
# 2019-06-27, BUY EXECUTED, Price: 70.19, Size: 2155.00, Comm 0.00
# 2019-07-22, MONTHLY CASH ADDED: new cash amount is 14586
# 2019-08-08, Pre-rebalancing CASH 14585.99, VALUE  806656.90, FUND SHARES 5067.97, FUND VALUE 159.17:
# 2019-08-08, SELL EXECUTED, Price: 716.62, Size: -253.00, Comm 0.00
# 2019-08-08, SELL EXECUTED, Price: 4788.49, Size: -24.00, Comm 0.00
# 2019-08-08, SELL EXECUTED, Price: 3937.37, Size: -38.00, Comm 0.00
# 2019-08-08, SELL EXECUTED, Price: 0.03, Size: -7633023.00, Comm 0.00
# 2019-08-08, SELL EXECUTED, Price: 72.53, Size: -2155.00, Comm 0.00
# 2019-08-08, BUY EXECUTED, Price: 716.62, Size: 226.00, Comm 0.00
# 2019-08-08, BUY EXECUTED, Price: 4788.49, Size: 33.00, Comm 0.00
# 2019-08-08, BUY EXECUTED, Price: 3937.37, Size: 41.00, Comm 0.00
# 2019-08-08, BUY EXECUTED, Price: 0.03, Size: 6402009.00, Comm 0.00
# 2019-08-08, BUY EXECUTED, Price: 72.53, Size: 2233.00, Comm 0.00
# 2019-08-20, MONTHLY CASH ADDED: new cash amount is 14513
# 2019-09-19, Pre-rebalancing CASH 14513.29, VALUE  848742.57, FUND SHARES 5128.11, FUND VALUE 165.51:
# 2019-09-19, SELL EXECUTED, Price: 720.41, Size: -226.00, Comm 0.00
# 2019-09-19, SELL EXECUTED, Price: 5610.57, Size: -33.00, Comm 0.00
# 2019-09-19, SELL EXECUTED, Price: 4178.71, Size: -41.00, Comm 0.00
# 2019-09-19, SELL EXECUTED, Price: 0.03, Size: -6402009.00, Comm 0.00
# 2019-09-19, SELL EXECUTED, Price: 71.30, Size: -2233.00, Comm 0.00
# 2019-09-19, BUY EXECUTED, Price: 720.41, Size: 236.00, Comm 0.00
# 2019-09-19, BUY EXECUTED, Price: 5610.57, Size: 30.00, Comm 0.00
# 2019-09-19, BUY EXECUTED, Price: 4178.71, Size: 40.00, Comm 0.00
# 2019-09-19, BUY EXECUTED, Price: 0.03, Size: 6815084.00, Comm 0.00
# 2019-09-19, BUY EXECUTED, Price: 71.30, Size: 2393.00, Comm 0.00
# 2019-09-20, MONTHLY CASH ADDED: new cash amount is 16567
# 2019-10-21, MONTHLY CASH ADDED: new cash amount is 26567
# 2019-10-31, Pre-rebalancing CASH 26566.73, VALUE  857826.29, FUND SHARES 5250.64, FUND VALUE 163.38:
# 2019-10-31, SELL EXECUTED, Price: 730.85, Size: -236.00, Comm 0.00
# 2019-10-31, SELL EXECUTED, Price: 5204.52, Size: -30.00, Comm 0.00
# 2019-10-31, SELL EXECUTED, Price: 4286.18, Size: -40.00, Comm 0.00
# 2019-10-31, SELL EXECUTED, Price: 0.03, Size: -6815084.00, Comm 0.00
# 2019-10-31, SELL EXECUTED, Price: 72.59, Size: -2393.00, Comm 0.00
# 2019-10-31, BUY EXECUTED, Price: 730.85, Size: 239.00, Comm 0.00
# 2019-10-31, BUY EXECUTED, Price: 5204.52, Size: 33.00, Comm 0.00
# 2019-10-31, BUY EXECUTED, Price: 4286.18, Size: 40.00, Comm 0.00
# 2019-10-31, BUY EXECUTED, Price: 0.03, Size: 6851460.00, Comm 0.00
# 2019-10-31, BUY EXECUTED, Price: 72.59, Size: 2408.00, Comm 0.00
# 2019-11-20, MONTHLY CASH ADDED: new cash amount is 16743
# 2019-12-12, Pre-rebalancing CASH 16743.45, VALUE  888122.65, FUND SHARES 5310.82, FUND VALUE 167.23:
# 2019-12-12, SELL EXECUTED, Price: 668.34, Size: -239.00, Comm 0.00
# 2019-12-12, SELL EXECUTED, Price: 5770.34, Size: -33.00, Comm 0.00
# 2019-12-12, SELL EXECUTED, Price: 4855.74, Size: -40.00, Comm 0.00
# 2019-12-12, SELL EXECUTED, Price: 0.02, Size: -6851460.00, Comm 0.00
# 2019-12-12, SELL EXECUTED, Price: 70.33, Size: -2408.00, Comm 0.00
# 2019-12-12, BUY EXECUTED, Price: 668.34, Size: 263.00, Comm 0.00
# 2019-12-12, BUY EXECUTED, Price: 5770.34, Size: 30.00, Comm 0.00
# 2019-12-12, BUY EXECUTED, Price: 4855.74, Size: 36.00, Comm 0.00
# 2019-12-12, BUY EXECUTED, Price: 0.02, Size: 7992606.00, Comm 0.00
# 2019-12-12, BUY EXECUTED, Price: 70.33, Size: 2507.00, Comm 0.00
# 2019-12-20, MONTHLY CASH ADDED: new cash amount is 15300
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# See C:\Users\feder\Desktop\portfolio-allocation\output\example_uniform_2020-07-29.pdf for report with backtest results.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2015-01-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-01-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>62</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>53.664%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>825.079%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>20.694%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.18</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>3.30</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-16.283%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.53</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>3.96</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>1.46</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>8.22</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.28</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.428%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>0.73</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>2.192%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16.28</td>
#       <td>2016-08-23</td>
#       <td>2016-11-14</td>
#       <td>2017-01-05</td>
#       <td>98</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>14.64</td>
#       <td>2018-01-26</td>
#       <td>2018-02-09</td>
#       <td>2018-05-24</td>
#       <td>85</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>13.73</td>
#       <td>2015-10-28</td>
#       <td>2015-11-13</td>
#       <td>2016-01-21</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>13.42</td>
#       <td>2018-10-02</td>
#       <td>2018-12-24</td>
#       <td>2019-01-30</td>
#       <td>87</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10.12</td>
#       <td>2017-02-24</td>
#       <td>2017-03-14</td>
#       <td>2017-04-04</td>
#       <td>28</td>
#     </tr>
#   </tbody>
# </table>
# <img src="data:image/png;base64,..." width="1008">

# %% [markdown]
# ### 2. Historical data, custom weights

# %%
# %run main --historic  "medium" --weights "0.2, 0.3, 0.1, 0.1, 0.3" --initial_cash 100000 --monthly_cash 10000 --create_report --report_name example --startdate "2015-01-01" --enddate "2020-01-01" --system windows --leverage 3

# %% [markdown]
# ### 3. Automatically downloaded data, custom weights

# %%
# %run main --shares "SPY,IWM,TLT,GLD," --shareclass "equity,equity,bond_lt,gold" --weights "0.2, 0.3, 0.1, 0.4" --initial_cash 100000 --monthly_cash 10000 --create_report --report_name example --startdate "2015-01-01" --enddate "2020-01-01" --system windows --leverage 3

# %% [markdown]
# ### 4. Automatically downloaded data, 60-40 strategy

# %%
# %run main --shares "SPY,IWM,TLT,GLD," --shareclass "equity,equity,bond_lt,gold" --strategy sixtyforty --initial_cash 100000 --monthly_cash 10000 --create_report --report_name example --startdate "2015-01-01" --enddate "2020-01-01" --system windows --leverage 3

# %% [markdown]
# ### 5. Multiple strategies backtest

# %%
# %run main --shares "UPRO,TQQQ,UGLD,TYD,TMF,UTSL" --shareclass "equity,equity,gold,bond_it,bond_lt,commodity" --strategy riskparity_nested,riskparity,riskparity_pylib --initial_cash 1000000 --monthly_cash 0 --create_report --report_name MyCurrentPortfolio --startdate "2019-06-01" --enddate "2020-08-01" --system windows --leverage 1
# Out:
# C:\Users\feder\Anaconda3\envs\portfolio-allocation\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
# C:\Users\feder\Anaconda3\envs\portfolio-allocation\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(
# ##############################################################################
# ##############################################################################
# ### Backtest starting
# ###  Parameters:
# ###    --historic None
# ###    --shares UPRO,TQQQ,UGLD,TYD,TMF,UTSL
# ###    --shareclass equity,equity,gold,bond_it,bond_lt,commodity
# ###    --weights
# ###    --indicators False
# ###    --initial_cash 1000000
# ###    --monthly_cash 0.0
# ###    --create_report True
# ###    --report_name MyCurrentPortfolio
# ###    --strategy riskparity_nested,riskparity,riskparity_pylib
# ###    --startdate 2019-06-01
# ###    --enddate 2020-08-01
# ###    --system windows
# ###    --leverage 1
# ##############################################################################
# ##############################################################################
# ###
# ### Backtest strategy: riskparity_nested
# ###
# ##############################################################################
# 2020-02-19, Pre-rebalancing CASH 1000000.00, VALUE  1000000.00, FUND SHARES 10000.00, FUND VALUE 100.00:
# 2020-02-19, BUY EXECUTED, Price: 80.17, Size: 1657.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 118.06, Size: 911.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 166.38, Size: 955.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 55.46, Size: 5668.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 31.72, Size: 4305.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 56.87, Size: 2629.00, Comm 0.00
# 2020-04-01, Pre-rebalancing CASH 321.15, VALUE  852331.44, FUND SHARES 10000.00, FUND VALUE 85.23:
# 2020-04-01, SELL EXECUTED, Price: 23.94, Size: -1657.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 41.73, Size: -911.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 152.44, Size: -955.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 67.88, Size: -5668.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 43.80, Size: -4305.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 17.29, Size: -2629.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 23.94, Size: 2092.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 41.73, Size: 1278.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 152.44, Size: 895.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 67.88, Size: 5937.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 43.80, Size: 2997.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 17.29, Size: 3933.00, Comm 0.00
# 2020-05-14, Pre-rebalancing CASH 227.50, VALUE  930419.37, FUND SHARES 10000.00, FUND VALUE 93.04:
# 2020-05-14, SELL EXECUTED, Price: 35.58, Size: -2092.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 71.66, Size: -1278.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 191.98, Size: -895.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 68.17, Size: -5937.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 43.42, Size: -2997.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 19.35, Size: -3933.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 35.58, Size: 1280.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 71.66, Size: 628.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 191.98, Size: 410.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 68.17, Size: 8587.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 43.42, Size: 3231.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 19.35, Size: 2779.00, Comm 0.00
# 2020-06-26, Pre-rebalancing CASH 328.62, VALUE  961636.64, FUND SHARES 10000.00, FUND VALUE 96.16:
# 2020-06-26, SELL EXECUTED, Price: 40.80, Size: -1280.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 89.48, Size: -628.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 200.60, Size: -410.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 68.11, Size: -8587.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 41.67, Size: -3231.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 18.83, Size: -2779.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 40.80, Size: 1231.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 89.48, Size: 669.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 200.60, Size: 517.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 68.11, Size: 7632.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 41.67, Size: 3504.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 18.83, Size: 4403.00, Comm 0.00
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# Report: you are using data with daily frequency
# Report: you are using data with daily frequency
# Report: you are using data with daily frequency
# Report: you are using data with daily frequency
# See C:\Users\feder\Desktop\portfolio-allocation\output\MyCurrentPortfolio_riskparity_nested_2020-08-03.pdf for report with backtest results.
# Report: you are using data with daily frequency
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-07-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>14</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>4.288%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>5.038%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>22.157%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.30</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.14</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.11</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-31.605%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.10</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.40</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-1.50</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>16.72</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.26</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.765%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>0.39</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>7.96%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>31.60</td>
#       <td>2020-03-06</td>
#       <td>2020-03-18</td>
#       <td>2020-07-29</td>
#       <td>104</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>9.30</td>
#       <td>2020-02-21</td>
#       <td>2020-02-28</td>
#       <td>2020-03-05</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <img src="data:image/png;base64,..." width="1008">
# Report: you are using data with daily frequency
# Report: you are using data with daily frequency
# ##############################################################################
# ###
# ### Backtest strategy: riskparity
# ###
# ##############################################################################
# 2020-02-19, Pre-rebalancing CASH 1000000.00, VALUE  1000000.00, FUND SHARES 10000.00, FUND VALUE 100.00:
# 2020-02-19, BUY EXECUTED, Price: 80.17, Size: 2014.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 118.06, Size: 1063.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 166.38, Size: 896.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 55.46, Size: 5512.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 31.72, Size: 4141.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 56.87, Size: 2226.00, Comm 0.00
# 2020-04-01, Pre-rebalancing CASH 345.41, VALUE  834677.08, FUND SHARES 10000.00, FUND VALUE 83.47:
# 2020-04-01, SELL EXECUTED, Price: 23.94, Size: -2014.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 41.73, Size: -1063.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 152.44, Size: -896.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 67.88, Size: -5512.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 43.80, Size: -4141.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 17.29, Size: -2226.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 23.94, Size: 2640.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 41.73, Size: 1712.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 152.44, Size: 790.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 67.88, Size: 5796.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 43.80, Size: 2831.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 17.29, Size: 2944.00, Comm 0.00
# 2020-05-14, Pre-rebalancing CASH 123.03, VALUE  924581.54, FUND SHARES 10000.00, FUND VALUE 92.46:
# 2020-05-14, SELL EXECUTED, Price: 35.58, Size: -2640.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 71.66, Size: -1712.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 191.98, Size: -790.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 68.17, Size: -5796.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 43.42, Size: -2831.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 19.35, Size: -2944.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 35.58, Size: 1649.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 71.66, Size: 858.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 191.98, Size: 364.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 68.17, Size: 8472.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 43.42, Size: 3099.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 19.35, Size: 2117.00, Comm 0.00
# 2020-06-26, Pre-rebalancing CASH 308.16, VALUE  965057.66, FUND SHARES 10000.00, FUND VALUE 96.51:
# 2020-06-26, SELL EXECUTED, Price: 40.80, Size: -1649.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 89.48, Size: -858.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 200.60, Size: -364.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 68.11, Size: -8472.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 41.67, Size: -3099.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 18.83, Size: -2117.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 40.80, Size: 1603.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 89.48, Size: 889.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 200.60, Size: 463.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 68.11, Size: 7634.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 41.67, Size: 3406.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 18.83, Size: 3374.00, Comm 0.00
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# Report: you are using data with daily frequency
# Report: you are using data with daily frequency
# Report: you are using data with daily frequency
# Report: you are using data with daily frequency
# See C:\Users\feder\Desktop\portfolio-allocation\output\MyCurrentPortfolio_riskparity_2020-08-03.pdf for report with backtest results.
# Report: you are using data with daily frequency
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-07-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>14</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>4.681%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>5.501%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>22.496%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.32</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.15</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.11</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-31.98%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.11</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.42</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-1.56</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>16.72</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.12</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.806%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>0.39</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>9.88%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>31.98</td>
#       <td>2020-03-06</td>
#       <td>2020-03-18</td>
#       <td>2020-07-16</td>
#       <td>95</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>9.90</td>
#       <td>2020-02-21</td>
#       <td>2020-02-28</td>
#       <td>2020-03-06</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.27</td>
#       <td>2020-07-22</td>
#       <td>2020-07-27</td>
#       <td>2020-07-29</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <img src="data:image/png;base64,..." width="1008">
# Report: you are using data with daily frequency
# Report: you are using data with daily frequency
# ##############################################################################
# ###
# ### Backtest strategy: riskparity_pylib
# ###
# ##############################################################################
# 2020-02-19, Pre-rebalancing CASH 1000000.00, VALUE  1000000.00, FUND SHARES 10000.00, FUND VALUE 100.00:
# 2020-02-19, BUY EXECUTED, Price: 80.17, Size: 2014.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 118.06, Size: 1063.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 166.38, Size: 896.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 55.46, Size: 5512.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 31.72, Size: 4141.00, Comm 0.00
# 2020-02-19, BUY EXECUTED, Price: 56.87, Size: 2226.00, Comm 0.00
# 2020-04-01, Pre-rebalancing CASH 345.41, VALUE  834677.08, FUND SHARES 10000.00, FUND VALUE 83.47:
# 2020-04-01, SELL EXECUTED, Price: 23.94, Size: -2014.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 41.73, Size: -1063.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 152.44, Size: -896.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 67.88, Size: -5512.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 43.80, Size: -4141.00, Comm 0.00
# 2020-04-01, SELL EXECUTED, Price: 17.29, Size: -2226.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 23.94, Size: 2641.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 41.73, Size: 1712.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 152.44, Size: 790.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 67.88, Size: 5795.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 43.80, Size: 2831.00, Comm 0.00
# 2020-04-01, BUY EXECUTED, Price: 17.29, Size: 2942.00, Comm 0.00
# 2020-05-14, Pre-rebalancing CASH 201.55, VALUE  924589.00, FUND SHARES 10000.00, FUND VALUE 92.46:
# 2020-05-14, SELL EXECUTED, Price: 35.58, Size: -2641.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 71.66, Size: -1712.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 191.98, Size: -790.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 68.17, Size: -5795.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 43.42, Size: -2831.00, Comm 0.00
# 2020-05-14, SELL EXECUTED, Price: 19.35, Size: -2942.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 35.58, Size: 1651.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 71.66, Size: 858.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 191.98, Size: 364.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 68.17, Size: 8476.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 43.42, Size: 3095.00, Comm 0.00
# 2020-05-14, BUY EXECUTED, Price: 19.35, Size: 2115.00, Comm 0.00
# 2020-06-26, Pre-rebalancing CASH 183.92, VALUE  965091.35, FUND SHARES 10000.00, FUND VALUE 96.51:
# 2020-06-26, SELL EXECUTED, Price: 40.80, Size: -1651.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 89.48, Size: -858.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 200.60, Size: -364.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 68.11, Size: -8476.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 41.67, Size: -3095.00, Comm 0.00
# 2020-06-26, SELL EXECUTED, Price: 18.83, Size: -2115.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 40.80, Size: 1603.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 89.48, Size: 889.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 200.60, Size: 463.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 68.11, Size: 7632.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 41.67, Size: 3408.00, Comm 0.00
# 2020-06-26, BUY EXECUTED, Price: 18.83, Size: 3374.00, Comm 0.00
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# Report: you are using data with daily frequency
# Report: you are using data with daily frequency
# Report: you are using data with daily frequency
# Report: you are using data with daily frequency
# See C:\Users\feder\Desktop\portfolio-allocation\output\MyCurrentPortfolio_riskparity_pylib_2020-08-03.pdf for report with backtest results.
# Report: you are using data with daily frequency
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-07-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>14</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>4.683%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>5.504%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>22.495%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.32</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.15</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.11</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-31.98%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.11</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.42</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-1.56</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>16.72</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.12</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.806%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>0.39</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>9.888%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>31.98</td>
#       <td>2020-03-06</td>
#       <td>2020-03-18</td>
#       <td>2020-07-16</td>
#       <td>95</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>9.90</td>
#       <td>2020-02-21</td>
#       <td>2020-02-28</td>
#       <td>2020-03-06</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.27</td>
#       <td>2020-07-22</td>
#       <td>2020-07-27</td>
#       <td>2020-07-29</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <img src="data:image/png;base64,..." width="1008">
# Report: you are using data with daily frequency
# Report: you are using data with daily frequency
# <img src="data:image/png;base64,..." width="432">
# See C:\Users\feder\Desktop\portfolio-allocation\output\Aggregated_Report.pdf for report with backtest results of different strategies.
